# %%
import torch

print(torch.cuda.is_available())
# Out:
# True

# %%
print(torch.cuda.current_device())

torch.cuda.get_device_name(0)
# Out:
# 0
# 'Tesla T4'

# %%
save_dir = '/content/drive/MyDrive/nutris yolo cnn/V1/runs'

# %%
from google.colab import drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 7.0 MB/s eta 0:00:00
# ...

# %%
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
from ultralytics import YOLO

model = YOLO()
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 69.5MB/s]

# %%
model.train(data="/content/drive/MyDrive/nutris yolo cnn/V1/data.yaml", epochs = 60, project=save_dir)
# Out:
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
model = YOLO('/content/drive/MyDrive/nutris yolo cnn/V1/runs/train7/weights/best.pt')
metrics = model.val(save_json = True, project=save_dir)  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.199 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/valid/labels.cache... 210 images, 0 backgrounds, 0 corrupt: 100%|██████████| 210/210 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:06<00:00,  2.01it/s]
#                    all        210        361      0.831      0.804      0.856      0.606
#                  arroz        210         50      0.775       0.92      0.879      0.629
#                  carne        210         59      0.646      0.589      0.681      0.419
#                 feijao        210         47      0.956      0.894      0.959      0.732
#                 frango        210         52      0.829      0.846      0.883       0.58
# ...

# %%
# !yolo task=detect mode=val model='/content/drive/MyDrive/nutris yolo cnn/V1/runs/train7/weights/best.pt' data="/content/drive/MyDrive/Teste imagem yolo cnn/V1/data.yaml" project='/content/drive/MyDrive/Teste imagem yolo cnn/V1/runs'
# Out:
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/18Fi8RZmEeZKprttDQqZBk6sP4li1wxhR/Teste imagem yolo cnn/V1/datasets/valid/labels.cache... 210 images, 0 backgrounds, 0 corrupt: 100% 210/210 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 14/14 [00:07<00:00,  1.95it/s]
#                    all        210        361      0.831      0.804      0.856      0.606
#                  arroz        210         50      0.775       0.92      0.879      0.629
#                  carne        210         59      0.646      0.589      0.681      0.419
#                 feijao        210         47      0.956      0.894      0.959      0.732
#                 frango        210         52      0.829      0.846      0.883       0.58
# ...

# %%
model.predict(save_txt=True,  conf=0.5, project=save_dir, source='/content/drive/MyDrive/nutris yolo cnn/V1/datasets/test/images', save=True)
# Out:
# image 1/9 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/0cf76fea-chicken_breast_18.png: 640x640 (no detections), 7.9ms
# image 2/9 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/20231016_184414.jpg: 640x480 1 bowl, 103.4ms
# image 3/9 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/20231016_184417.jpg: 640x480 1 knife, 6.5ms
# image 4/9 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/frango.jpg: 352x640 3 pizzas, 67.4ms
# image 5/9 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/pf1.jpg: 416x640 1 dining table, 65.6ms
# image 6/9 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/pf2.jpg: 448x640 1 fork, 63.3ms
# image 7/9 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/pf3.jpg: 320x640 (no detections), 64.7ms
# image 8/9 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/pf4.jpg: 448x640 (no detections), 7.1ms
# ...

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/nutris yolo cnn/V1/runs/train7/weights/best.pt' conf=0.5 source='/content/drive/MyDrive/nutris yolo cnn/V1/datasets/test/images' project='/content/drive/MyDrive/nutris yolo cnn/V1/runs'
# Out:
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/7 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/0cf76fea-chicken_breast_18.png: 640x640 1 frango, 10.0ms
# image 2/7 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/frango.jpg: 352x640 3 frangos, 90.3ms
# image 3/7 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/pf1.jpg: 416x640 1 arroz, 1 carne, 1 feijao, 1 ovo, 1 salada, 87.8ms
# image 4/7 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/pf2.jpg: 448x640 1 arroz, 1 carne, 1 feijao, 1 salada, 86.4ms
# image 5/7 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/pf3.jpg: 320x640 1 arroz, 1 carne, 1 feijao, 1 ovo, 87.7ms
# image 6/7 /content/drive/MyDrive/Teste imagem yolo cnn/V1/datasets/test/images/pf4.jpg: 448x640 1 arroz, 1 feijao, 2 saladas, 11.4ms
# ...
